# %% [markdown]
# <a href="https://colab.research.google.com/github/jortegadv/DU_CCF_technical-dicussion/blob/main/tech_comms_integration_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ingest

# %% [markdown]
# # EDA

# %% [markdown]
# # Modelling

# %% [markdown]
# # Conclusion

# %% [markdown]
# Sample of GitHub collaboration and sharing
